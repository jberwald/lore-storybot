# %%
import requests
import json
from datetime import datetime as dt

import torch

if torch.backends.mps.is_available():
    print("MPS is available!")
    mps_device = torch.device("mps")
else:
    print("MPS is not available on this device.")
    mps_device = torch.device("cpu") # Fallback to CPU if MPS is not available

from storybot.models import Entry
# Out:
# MPS is available!

# %%
file_dir = "./data"

# Load conversations
with open("/".join([file_dir, 'conversations.json']), 'r') as f:
    conversations = json.load(f)

# Load discussions
with open("/".join([file_dir, 'discussions.json']), 'r') as f:
    discussions = json.load(f)

# Load activity data
with open("/".join([file_dir, 'activity.json']), 'r') as f:
    activities = json.load(f)

# %%
conversations[0]
# Out:
# {'messages_list': [{'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-01T10:15:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'Hello StoryBot, I’m having a tough time with this app. My fingers aren’t what they used to be. Can you help me?'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-01T10:20:00Z',
#    'screen_name': 'StoryBot',
#    'message': "Hello ChattyPenguin! I’m here to help. Can you tell me what issues you're experiencing with the app?"},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-01T10:25:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': "It's just so complicated! I keep hitting the wrong buttons. And sometimes it logs me out unexpectedly."},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-01T10:30:00Z',
#    'screen_name': 'StoryBot',
#    'message': "That sounds frustrating! Unfortunately, I can't fix technical issues directly, but I can guide you on how to navigate it better if you'd like."},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-01T10:35:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'I’d appreciate that. My grandson usually helps, but he’s busy with school lately. I feel so helpless.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-01T10:40:00Z',
#    'screen_name': 'StoryBot',
#    'message': 'Let’s take it one step at a time. What’s the first thing you want to do on the app?'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-01T10:45:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'I’d like to read the daily stories! They used to lift my spirits.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-01T10:50:00Z',
#    'screen_name': 'StoryBot',
#    'message': "Great choice! You can find them in the 'Stories' section. Just tap on that menu. Let me know if you need help finding it."},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-02T11:15:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'I managed to get to the stories! But I’m feeling a bit down today. My health has been off, and I’m worried about my family.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-02T11:20:00Z',
#    'screen_name': 'StoryBot',
#    'message': 'I’m sorry to hear that, ChattyPenguin. It’s tough to feel unwell. Would you like to share more about what’s bothering you?'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-02T11:25:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'Well, I had a fall last week, and it shook me up. I remember back in the day, I slipped in the kitchen while baking. I thought I broke my hip then, but I learned to always be careful and mindful. That taught me to value my health and strength.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-02T11:30:00Z',
#    'screen_name': 'StoryBot',
#    'message': "That's a poignant lesson, ChattyPenguin. Prioritizing safety is always wise. Have you shared your recent concerns with family?"},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-03T12:00:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'I talked to my daughter about it. She said I should consider moving into assisted living, but I don’t want to leave my home.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-03T12:05:00Z',
#    'screen_name': 'StoryBot',
#    'message': 'That’s understandable. Your home holds many memories. It’s important to feel comfortable where you live. What are your favorite things about your home?'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-03T12:10:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'My garden is beautiful, and I love my cozy chair by the window. But, I guess I worry about being safe alone.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-03T12:15:00Z',
#    'screen_name': 'StoryBot',
#    'message': "It's great that you have a lovely garden to enjoy! Finding ways to make your space safer could ease some worries. Would you like tips on that?"},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-03T12:20:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'Yes, please! I want to stay here for as long as I can.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-03T12:25:00Z',
#    'screen_name': 'StoryBot',
#    'message': 'Alright! Consider putting non-slip mats in the kitchen and bathroom, and make sure all the pathways in your home are clear. You can also have a personal alarm system.'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 782,
#    'transaction_datetime_utc': '2023-10-04T11:10:00Z',
#    'screen_name': 'ChattyPenguin',
#    'message': 'That sounds manageable! I’ll talk to my daughter about it. Thank you for being so helpful!'},
#   {'ref_conversation_id': 98696,
#    'ref_user_id': 1,
#    'transaction_datetime_utc': '2023-10-04T11:15:00Z',
#    'screen_name': 'StoryBot',
#    'message': "You're very welcome! It's always a pleasure to help. Let me know how the conversation goes with your daughter."}],
#  'ref_conversation_id': 98696,
#  'ref_user_id': 782}

# %%
feature_url = "http://127.0.0.1:8000/extract_sentiment"
db_url = "http://127.0.0.1:8001/entry"

# conv = conversations[1]


headers = {
    "Content-Type": "application/json"
}

# Mimic a streaming conversation
for conv in conversations[:2]:
    for message in conv['messages_list']:
        # Inefficient multiple lookup
        user_id = message['ref_user_id']
        conversation_id = message['ref_conversation_id']
        screen_name = message['screen_name']
        
        if message['ref_user_id'] == 1:
            continue
        
        payload = {
            "message": message['message'],
            "metadata": {
                "user_id": user_id,
                "conversation_id": conversation_id,
                "screen_name": screen_name,
                "timestamp": message['transaction_datetime_utc']
            }
        }
        
        try:
            feature_response = requests.post(feature_url, headers=headers, json=payload)
        
            # Check if the request was successful (status code 2xx)
            if feature_response.status_code >= 200 and feature_response.status_code < 300:
                print("API Response:")
                print(json.dumps(feature_response.json(), indent=2))
            else:
                print(f"Error: API request failed with status code {response.status_code}")
                print(f"Response content: {feature_response.text}")
                
        except requests.exceptions.RequestException as e:
            print(f"An error occurred during the request: {e}")
    
        try:
            item = Entry(**feature_response.json())
            db_response = requests.post(db_url, headers=headers, data=item.model_dump_json())
          
            if db_response.status_code >= 200 and db_response.status_code < 300:
                print("DB API Response:")
                print(json.dumps(db_response.json(), indent=2))
            else: 
                print(f"Error: DB API request failed with status code {db_response.status_code}")
                print(f"Response content: {db_response.text}")
                
        except requests.exceptions.RequestException as e:
            print(f"An error occurred during the request: {e}")
# Out:
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.065,
#       "neu": 0.819,
#       "pos": 0.116,
#       "compound": 0.296
#     },
#     "top_sentiment": {
#       "label": "sadness",
#       "score": 0.4427511990070343
#     },
#     "summary": {
#       "summary_text": "Hello StoryBot, I\u2019m having a tough time with this app. My fingers aren\u2019t what they used to be. Can you help me?"
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-01T10:15:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 1
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.184,
#       "neu": 0.816,
#       "pos": 0.0,
#       "compound": -0.5255
#     },
#     "top_sentiment": {
#       "label": "surprise",
#       "score": 0.7161477208137512
#     },
#     "summary": {
#       "summary_text": "It's just so complicated! I keep hitting the wrong buttons. And sometimes it logs me out unexpectedly. I'm not sure I'm ever going to get the hang of it."
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-01T10:25:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 2
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.241,
#       "neu": 0.592,
#       "pos": 0.166,
#       "compound": -0.5646
#     },
#     "top_sentiment": {
#       "label": "fear",
#       "score": 0.48230403661727905
#     },
#     "summary": {
#       "summary_text": "I\u2019d appreciate that. My grandson usually helps, but he\u2019s busy with school lately. I feel so helpless."
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-01T10:35:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 3
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.811,
#       "pos": 0.189,
#       "compound": 0.4199
#     },
#     "top_sentiment": {
#       "label": "joy",
#       "score": 0.8809493780136108
#     },
#     "summary": {
#       "summary_text": "I\u2019d like to read the daily stories! They used to lift my spirits. I\u2019m glad you are back!"
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-01T10:45:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 4
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.12,
#       "neu": 0.813,
#       "pos": 0.068,
#       "compound": -0.3274
#     },
#     "top_sentiment": {
#       "label": "sadness",
#       "score": 0.594653844833374
#     },
#     "summary": {
#       "summary_text": "I managed to get to the stories! But I\u2019m feeling a bit down today. My health has been off, and I\u2019m worried about my family. I\u2019ve been trying to stay positive, but it\u2019s been a struggle. I\u2019m going to try to get back to my regular schedule tomorrow.\nThis entry was posted in Uncategorized and tagged 2019, 365, 365 project, art, art journal, art journaling, art journaling 365, art journaling daily, art journaling daily 365, art journaling every day, art journaling every day 365, art journaling every day daily, art journaling every"
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-02T11:15:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 5
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.061,
#       "neu": 0.726,
#       "pos": 0.213,
#       "compound": 0.8294
#     },
#     "top_sentiment": {
#       "label": "fear",
#       "score": 0.8986001014709473
#     },
#     "summary": {
#       "summary_text": "Well, I had a fall last week, and it shook me up. I remember back in the day, I slipped in the kitchen while baking. I thought I broke my hip then, but I learned to always be careful and mindful. That taught me to value my health and strength. I am so thankful for the strength of my body, and I am so grateful for the strength of my faith in God. He is my strength, and I am so thankful for that.\nI am not one to dwell on the past, but I am one to learn from it. I am one to take what I learned from it, and I am one to use it to grow and to learn. I am one to use it to be a better person, and to be a better me."
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-02T11:25:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 6
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.06,
#       "neu": 0.874,
#       "pos": 0.067,
#       "compound": 0.0387
#     },
#     "top_sentiment": {
#       "label": "sadness",
#       "score": 0.8482467532157898
#     },
#     "summary": {
#       "summary_text": "I talked to my daughter about it. She said I should consider moving into assisted living, but I don\u2019t want to leave my home. She said I should get help with my meals, but I like to cook. I don\u2019t know what to do. What can you suggest?\nI don\u2019t know how old you are, but I am 78 and my husband is 80. We have been married 57 years. We have a home in the country, and I have always cooked and taken care of our home. I know you are concerned about your independence, but you can\u2019t do it all by yourself. I was in"
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-03T12:00:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 7
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.217,
#       "neu": 0.479,
#       "pos": 0.304,
#       "compound": 0.3716
#     },
#     "top_sentiment": {
#       "label": "fear",
#       "score": 0.8472673892974854
#     },
#     "summary": {
#       "summary_text": "My garden is beautiful, and I love my cozy chair by the window. But, I guess I worry about being safe alone. I am 65 and have lived alone for 20 years. I have had my home broken into twice. I have been in the process of buying a gun for protection, but I am afraid. I have a small dog, and I am afraid of what I will do if someone comes into my house. I am a little nervous about the gun, but I am afraid. I am afraid of being alone. I am afraid of the dark. I am afraid of being attacked. I am afraid"
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-03T12:10:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 8
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.548,
#       "pos": 0.452,
#       "compound": 0.68
#     },
#     "top_sentiment": {
#       "label": "sadness",
#       "score": 0.3620278239250183
#     },
#     "summary": {
#       "summary_text": "Yes, please! I want to stay here for as long as I can. I have been on a mission to find the perfect home for the last 8 years. I have been in a few homes and they were good, but this one is the best. The view of the lake and the mountains is amazing. The sunsets are breathtaking. The food is delicious. The staff is friendly and helpful. The house is clean and well-maintained. The location is perfect. It is close to everything, but far enough away from the city to be peaceful and quiet."
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-03T12:20:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 9
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.676,
#       "pos": 0.324,
#       "compound": 0.7718
#     },
#     "top_sentiment": {
#       "label": "joy",
#       "score": 0.6928727030754089
#     },
#     "summary": {
#       "summary_text": "That sounds manageable! I\u2019ll talk to my daughter about it. Thank you for being so helpful!"
#     },
#     "metadata": {
#       "user_id": 782,
#       "conversation_id": 98696,
#       "screen_name": "ChattyPenguin",
#       "timestamp": "2023-10-04T11:10:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 10
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.063,
#       "neu": 0.837,
#       "pos": 0.1,
#       "compound": 0.2247
#     },
#     "top_sentiment": {
#       "label": "sadness",
#       "score": 0.7455880641937256
#     },
#     "summary": {
#       "summary_text": "Hello, StoryBot. I\u2019m having a tough time with this app. It keeps logging me out, and I can't seem to type very well today. I hope this is helpful.\nHi, I'm having trouble logging in. I'm not sure what the problem is. I hope this is helpful.\nHi, I'm having trouble logging in. I'm not sure what the problem is. I hope this is helpful.\nHi, I'm having trouble logging in. I'm not sure what the problem is. I hope this is helpful.\nHi, I'm having trouble logging in. I'm not sure what the problem is. I hope this is"
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-01T09:00:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 11
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.082,
#       "neu": 0.918,
#       "pos": 0.0,
#       "compound": -0.1759
#     },
#     "top_sentiment": {
#       "label": "neutral",
#       "score": 0.6069098711013794
#     },
#     "summary": {
#       "summary_text": "Not yet! I\u2019ll give that a try. Meanwhile, my knees are acting up again. It\u2019s hard to get up and down. I think it\u2019s the result of a bad fall last year. I have been in physical therapy for a while. It\u2019s helped but I\u2019m not sure if it\u2019s the same thing.\nI\u2019m trying to keep a positive attitude. I think it\u2019s important to do that. I\u2019m also trying to keep my mind active. I\u2019m reading a lot and I\u2019m doing a lot of puzzles. I think that helps.\nI have a friend who is a nurse. She says that she has seen"
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-01T09:05:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 12
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.779,
#       "pos": 0.221,
#       "compound": 0.6249
#     },
#     "top_sentiment": {
#       "label": "neutral",
#       "score": 0.8922768831253052
#     },
#     "summary": {
#       "summary_text": "Yes, but they just tell me to rest. It feels like I\u2019m just sitting around these days, not doing much. I don\u2019t feel like I\u2019m doing much, but I know I am. I just can\u2019t tell you what I\u2019m doing.\nI\u2019m not sure what to do with my time. I have no idea what to do with my time. I have no idea what to do with my time. I have no idea what to do with my time. I have no idea what to do with my time. I have no idea what to do with my time. I have no idea what to do"
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-01T09:10:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 13
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.168,
#       "neu": 0.506,
#       "pos": 0.326,
#       "compound": 0.128
#     },
#     "top_sentiment": {
#       "label": "fear",
#       "score": 0.9899147748947144
#     },
#     "summary": {
#       "summary_text": "I like reading. Just finished a mystery novel, but I'm feeling a bit restless again. I've been reading for 30 minutes, but I'm not getting anywhere. I need something to focus on. I'm not in the mood to work on my novel, or even to write a blog post. I don't know what I'm in the mood for, but I know I need to do something. I'm not feeling very productive, but I know I need to be. I'm not feeling very creative, but I know I need to be. I'm not feeling very inspired"
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-02T09:20:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 14
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.87,
#       "pos": 0.13,
#       "compound": 0.2732
#     },
#     "top_sentiment": {
#       "label": "joy",
#       "score": 0.6544724106788635
#     },
#     "summary": {
#       "summary_text": "I used to enjoy painting, but it\u2019s been a long time. Maybe I\u2019ll pick it up again\u2026..\nI love the way you\u2019ve captured the \u201cfeel\u201d of the painting. Great job.\nI used to love painting but haven\u2019t done it in a long time. I think it would be good for me to get back into it.\nLove this painting, and the way you captured the feeling of it."
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-02T09:25:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 15
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.838,
#       "pos": 0.162,
#       "compound": 0.644
#     },
#     "top_sentiment": {
#       "label": "neutral",
#       "score": 0.5634358525276184
#     },
#     "summary": {
#       "summary_text": "Mostly landscapes. I loved capturing the colors of sunsets. Speaking of colors, what do you think about life? What's the point of all this? I'm just wondering, that's all."
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-03T09:30:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 16
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.213,
#       "neu": 0.787,
#       "pos": 0.0,
#       "compound": -0.5023
#     },
#     "top_sentiment": {
#       "label": "sadness",
#       "score": 0.96094810962677
#     },
#     "summary": {
#       "summary_text": "I suppose it\u2019s about those connections, but sometimes I feel lonely, even with family nearby. I have a hard time explaining to my family why I\u2019m so sad sometimes, because I don\u2019t know how to explain it. I guess I just need to keep going, but it\u2019s hard.\nSometimes I think about the fact that I\u2019m not married, and I think I\u2019d like to be, but I don\u2019t know if I\u2019m ready. I don\u2019t know if I\u2019m good enough, or if I\u2019m ready for a relationship. I don\u2019t know what I\u2019m looking for,"
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-04T09:35:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 17
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 1.0,
#       "pos": 0.0,
#       "compound": 0.0
#     },
#     "top_sentiment": {
#       "label": "surprise",
#       "score": 0.6208680272102356
#     },
#     "summary": {
#       "summary_text": "I did! My granddaughter called me yesterday. We talked for an hour about her new job. She has been working at a local grocery store for a few weeks and is now working at a fast food restaurant. She is so happy. She is also going to college in the fall. I am so proud of her."
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-05T09:40:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 18
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.513,
#       "pos": 0.487,
#       "compound": 0.923
#     },
#     "top_sentiment": {
#       "label": "joy",
#       "score": 0.9858426451683044
#     },
#     "summary": {
#       "summary_text": "It made me feel happy! Family can be a great comfort. Just wish I could do more things with them. But I am glad that I have the opportunity to talk to them, to see them, to feel them. They are all good people. I love them. I hope they know that I love them. I hope they know that they are always in my thoughts. I hope they know that I will always be there for them.\nI have to admit, I did not know what to expect when I came to the Philippines. I had heard a lot of good things about it, but I had also"
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-06T09:45:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 19
#   }
# }
# API Response:
# {
#   "response": {
#     "vader_scores": {
#       "neg": 0.0,
#       "neu": 0.681,
#       "pos": 0.319,
#       "compound": 0.7263
#     },
#     "top_sentiment": {
#       "label": "joy",
#       "score": 0.7579607963562012
#     },
#     "summary": {
#       "summary_text": "That\u2019s a good idea! I\u2019ll suggest a picnic in the park next time we chat. Thanks, StoryBot."
#     },
#     "metadata": {
#       "user_id": 360,
#       "conversation_id": 38080,
#       "screen_name": "CuriousPeach",
#       "timestamp": "2023-10-08T09:50:00Z"
#     }
#   }
# }
# DB API Response:
# {
#   "response": {
#     "id": 20
#   }
# }

# %%
user_id = 782

# db_url = "http://127.0.0.1:8001/messages"
db_url = "http://127.0.0.1:8001/top-features"

headers = {
    "Content-Type": "application/json"
}

payload = {
    "user_id": user_id
}

resp = requests.post(db_url, headers=headers, json=payload)

# %%
resp = resp.json()['response']
resp
# Out:
# {'afraid': 2.7047480922384253,
#  'afraid afraid': 2.7047480922384253,
#  'afraid attacked': 2.7047480922384253,
#  'afraid comes': 2.7047480922384253,
#  'afraid dark': 2.7047480922384253}

# %%
from dataclasses import dataclass, field
from typing import List, Dict
from collections import defaultdict

from sklearn.feature_extraction.text import TfidfVectorizer
import scipy.sparse as sp


@dataclass
class MessageProcessor:

    conversation: List[dict] | dict
    messages: List = field(default_factory=list)

    tfidf_matrix: sp.spmatrix = None
    tfidf_vectorizer: TfidfVectorizer = None

    def __post_init__(self):
        # strip the 'response' key off
        if isinstance(self.conversation, dict) and 'response' in self.conversation.keys():
            self.conversation = self.conversation['response']

        self._process_messages()
    
    def _process_messages(self):
        for msg in self.conversation:
            self.messages.append(msg['message'])

    def set_tfidf_message_matrix(self):
        # self.tfidf_vectorizer = TfidfVectorizer()
        self.tfidf_vectorizer = TfidfVectorizer(
            stop_words='english', 
            ngram_range=(1, 2),
            token_pattern=r'\b[a-zA-Z]+\b'
        )

        self.tfidf_vectorizer.fit(self.messages)

        self.tfidf_matrix = self.tfidf_vectorizer.transform(self.messages)


    def get_top_features(self, max_features: int=5):
        
        feature_names = self.tfidf_vectorizer.get_feature_names_out()

        # Get the IDF (Inverse Document Frequency) scores
        idf_scores = self.tfidf_vectorizer.idf_
        
        # Create a list of (feature, idf_score) tuples
        feature_idf_pairs = list(zip(feature_names, idf_scores))
        
        # Sort the list by IDF score in descending order (higher IDF means more important)
        sorted_features_by_importance = sorted(feature_idf_pairs, key=lambda item: item[1], reverse=True)

        return sorted_features_by_importance[:max_features]

# %%
ms = MessageProcessor(resp)
ms.get_tfidf_message_matrix()

# %%
top = ms.get_top_features(max_features=10)
top
# Out:
# [('afraid', np.float64(2.7047480922384253)),
#  ('afraid afraid', np.float64(2.7047480922384253)),
#  ('afraid attacked', np.float64(2.7047480922384253)),
#  ('afraid comes', np.float64(2.7047480922384253)),
#  ('afraid dark', np.float64(2.7047480922384253)),
#  ('afraid small', np.float64(2.7047480922384253)),
#  ('amazing', np.float64(2.7047480922384253)),
#  ('amazing sunsets', np.float64(2.7047480922384253)),
#  ('app', np.float64(2.7047480922384253)),
#  ('app fingers', np.float64(2.7047480922384253))]

# %%
top = {token: float(val) for token, val in top}
top
# Out:
# {'afraid': 2.7047480922384253,
#  'afraid afraid': 2.7047480922384253,
#  'afraid attacked': 2.7047480922384253,
#  'afraid comes': 2.7047480922384253,
#  'afraid dark': 2.7047480922384253,
#  'afraid small': 2.7047480922384253,
#  'amazing': 2.7047480922384253,
#  'amazing sunsets': 2.7047480922384253,
#  'app': 2.7047480922384253,
#  'app fingers': 2.7047480922384253}
